# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# %%
path=("/Users/alejandronaranjo/OneDrive - Universidad de San Buenaventura Medellín/03. Investigación/08 Inv. Adaptabilidad/06 Python_adaptab/01 Datos")
os.listdir(path)
os.chdir(path)

# %%
ls
# Out:
# BaseCSV_adap_complem.csv           Sens_Ciudad_Sexo.png
# BaseCSV_adap_orig.csv              SensacPref_RelacVotosNormaliz.png
# CSV_SinCartagena.csv               SensacRelacVotosNormaliz.png
# PrefRelacVotosNormaliz.png         VotosNormalizadosSuma.csv
# Pref_Ciudad_Sexo.png               adapta_junio29.csv
# ProcesamDatos_4Nov2019.xlsx*       sensac_pref_orig.csv
# SensPref_Temp_Ciudad.png

# %%
lucas = pd.read_csv("adapta_junio29.csv", index_col='Unnamed: 0')

#lucas.info()
lucas.head()
lucas
# Out:
#         Ciudad genero  edad  SensaciónVisual  SensaciónVisualNormalizada  \
# 0      Armenia      F  23.0              2.0                         0.0
# 1      Armenia      F  23.0              2.0                         0.0
# 2      Armenia      F  23.0              1.0                         0.5
# 3      Armenia      F  23.0              1.0                         0.5
# 4      Armenia      M  20.0              0.0                         1.0
# ...        ...    ...   ...              ...                         ...
# 1137  Medellín      M  21.0             -1.0                         0.5
# 1138  Medellín      M  20.0              0.0                         1.0
# 1139  Medellín      M  20.0              0.0                         1.0
# 1140  Medellín      M  20.0              0.0                         1.0
# 1141  Medellín      M  20.0              0.0                         1.0
#
#       PreferenciaVisual  PreferenciaVisualNormalizado  SensaciónTérmica  \
# ...

# %%
frio = lucas.loc[((lucas["SensaciónTérmica"] < 0))]
#frio.describe()

agradable = lucas.loc[((lucas["SensaciónTérmica"] == 0))]

calor = lucas.loc[((lucas["SensaciónTérmica"] > 0))]
calor
# Out:
#         Ciudad genero  edad  SensaciónVisual  SensaciónVisualNormalizada  \
# 0      Armenia      F  23.0              2.0                         0.0
# 1      Armenia      F  23.0              2.0                         0.0
# 2      Armenia      F  23.0              1.0                         0.5
# 3      Armenia      F  23.0              1.0                         0.5
# 4      Armenia      M  20.0              0.0                         1.0
# ...        ...    ...   ...              ...                         ...
# 1128  Medellín      F  18.0             -1.0                         0.5
# 1133  Medellín      M  21.0              1.0                         0.5
# 1135  Medellín      M  21.0              0.0                         1.0
# 1137  Medellín      M  21.0             -1.0                         0.5
# 1138  Medellín      M  20.0              0.0                         1.0
#
#       PreferenciaVisual  PreferenciaVisualNormalizado  SensaciónTérmica  \
# ...

# %%
fig_1 = plt.figure(1, figsize=(6,6))

x=calor["TEMP"]
y=calor['EV_media']
#diam=calor["SensaciónTérmica"]

chart_1 = fig_1.add_subplot(111)
#fig,ax=plt.subplots(figsize=(5,5))

chart_1.scatter(x, y, c="red", alpha=0.8, 
                edgecolor="dimgrey", linewidth=0.5, 
                label = "Calor", marker="^")
#plt.scatter(x, y, c="aquamarine", alpha=0.8, edgecolor="dimgrey", linewidth=0.5)

ax.set_xlabel("Temperatura (Cº)", fontsize=14)
ax.set_ylabel("Ilimunancia (Lux)", fontsize=14)

plt.ylim(0,1000)
plt.title("Sensación térmica según temperatura e iluminancia", fontsize=16)


chart_1 = fig_1.add_subplot(111)
x=frio["TEMP"]
y=frio['EV_media']

chart_1.scatter(x, y, c="blue", alpha=0.8, 
                edgecolor="dimgrey", linewidth=0.5, 
                label = "frio", marker="v")


chart_1 = fig_1.add_subplot(111)
x=agradable["TEMP"]
y=agradable['EV_media']

chart_1.scatter(x, y, c="None", edgecolors="gray", linewidth=0.7, 
                label = "agradable", marker="o")


plt.ylim(0,1000)
plt.title("Sensación térmica según temperatura e iluminancia", fontsize=16)
plt.xlabel("Temperatura [ºC]", fontsize=12)
plt.ylabel("Iluminancia [Lux]", fontsize=12)

plt.legend(bbox_to_anchor=(1.03, 1), loc='upper left',
           borderaxespad=0, frameon=False)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
sns.lmplot(x="TEMP",y='EV_media', data=lucas,
           fit_reg=False, hue='SensaciónTérmica', legend=True,
          palette=sns.color_palette("coolwarm", 7), markers= ["v", "v", "v", "o", "^", "^", "^"])
 
#plt.legend(bbox_to_anchor=(1.1, 1), loc='upper left', borderaxespad=0)

plt.xlabel("Temperatura")
plt.ylabel("Iluminancia")

#plt.savefig('01.TempIlum_SensTerm.png', transparent=True, dpi=300)
# Out:
# Text(37.68195068359374, 0.5, 'Iluminancia')

# %%
sns.lmplot(x="EV_media",y='TEMP', data=lucas,
           fit_reg=False, hue='SensaciónTérmica', legend=True,
          palette=sns.color_palette("coolwarm", 7), markers= ["v", "v", "v", "o", "^", "^", "^"])
 
#plt.legend(bbox_to_anchor=(1.1, 1), loc='upper left', borderaxespad=0)

plt.xlabel("Iluminancia")
plt.ylabel("Temperatura")
# Out:
# Text(33.08025390625, 0.5, 'Temperatura')

# %%
sns.lmplot(x="EV_media",y='TEMP', data=lucas,
           fit_reg=False, hue='SensaciónVisual', legend=True,
          palette=sns.color_palette("coolwarm", 5),
           #markers= ["v", "v", "o", "^", "^" ])
            markers= ["x", "x", "x", "x", "x"])
 
#plt.legend(bbox_to_anchor=(1.1, 1), loc='upper left', borderaxespad=0)

#plt.xlim(0,300)
plt.xlim(0,1000)
plt.xlabel("Iluminancia")
plt.ylabel("Temperatura")
# Out:
# Text(31.8446875, 0.5, 'Temperatura')
